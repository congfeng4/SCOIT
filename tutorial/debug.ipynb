# %%
import numpy as np
import seaborn as sns

# %%
H = np.load('../embeddings.npz', allow_pickle=True)

# %%
H1, H2, H3 = H['embeddings']

# %%
H1d = H1.toarray()

# %%
sns.heatmap(H1d)
# Out:
# <Axes: >

# %%
H2d = H2.toarray()

# %%
sns.heatmap(H2d)
# Out:
# <Axes: >

# %%
def any_column_all_zero(x):
    return np.nonzero(np.all(x == 0, 1))

# %%
H3d = H3.toarray()

# %%
H1d.shape, H2d.shape, H3d.shape
# Out:
# ((224, 287), (61, 287), (2, 287))

# %%
any_column_all_zero(H1d), any_column_all_zero(H2d), any_column_all_zero(H3d)
# Out:
# ((array([], dtype=int64),), (array([5]),), (array([], dtype=int64),))
