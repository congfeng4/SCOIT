# %%
cd ..
# Out:
# /home/mscs/congfeng4/GuidedStudy/Code/SCOIT
# /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/IPython/core/magics/osm.py:417: UserWarning: using dhist requires you to install the `pickleshare` library.
#   self.shell.db['dhist'] = compress_dhist(dhist)[-100:]

# %%
pwd
# Out:
# '/home/mscs/congfeng4/GuidedStudy/Code/SCOIT'

# %%
from hgnn.hypergraph import *

# %%
train_data = np.load('./data/sc_GEM/train_data.npz', allow_pickle=True)
test_data = np.load('./data/sc_GEM/test_data.npz', allow_pickle=True)

# %%
td = train_data['train_data']
td.shape
# Out:
# (10931, 3)

# %%
train_data['nums_type']
# Out:
# array([224,  61,   2])

# %%
check_hypergraph_isolated_nodes(train_data['train_data'], train_data['nums_type'])
# Out:
# True

# %%
check_hypergraph_isolated_nodes(test_data['test_data'], train_data['nums_type'])
# Out:
# True

# %%
train_data = np.load('data_hypersagnn/GPS/train_data.npz', allow_pickle=True)
test_data = np.load('data_hypersagnn/GPS/test_data.npz', allow_pickle=True)

# %%
check_hypergraph_isolated_nodes(train_data['train_data'], train_data['nums_type'])
# Out:
# True

# %%
check_hypergraph_isolated_nodes(test_data['test_data'], train_data['nums_type'])
# Out:
# Detected isolated_nodes [(0, 131), (0, 132), (0, 6), (0, 135), (0, 8), (0, 9), (0, 137), (0, 12), (0, 140), (0, 141), (0, 142), (0, 144), (0, 145), (0, 21), (0, 28), (0, 30), (0, 35), (0, 36), (0, 40), (0, 43), (0, 46), (0, 48), (0, 53), (0, 54), (0, 56), (0, 58), (0, 60), (0, 63), (0, 69), (0, 79), (0, 80), (0, 81), (0, 82), (0, 84), (0, 87), (0, 88), (0, 89), (0, 96), (0, 98), (0, 99), (0, 103), (0, 108), (0, 109), (0, 110), (0, 113), (0, 116), (0, 123), (0, 125), (0, 127), (1, 0), (1, 3), (1, 8), (1, 10), (1, 16), (1, 18), (1, 20), (1, 22), (1, 24), (1, 27), (1, 34), (1, 35), (1, 37), (1, 40), (1, 42), (1, 43), (1, 44), (1, 58), (1, 60), (1, 65), (1, 66), (1, 68), (1, 69)]
# False
