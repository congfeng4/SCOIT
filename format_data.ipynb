# %% [markdown]
# ## Convert all graphs to Hyper_SAGNN format.

# %%
try:
   import sys
   del sys.modules['hgnn.hypergraph']
except:
    pass

from hgnn.hypergraph import *
from pathlib import Path

TRAIN_SIZE = 0.8

# %%
for subdir in Path('./data').iterdir():
    if not subdir.is_dir():
        continue
    try:
        hg = load_graph(subdir)
    except Exception as e:
        print('Failed to load', subdir, 'except', e)
        continue
    convert_to_hypersagnn_format(hg, TRAIN_SIZE, subdir, normalization=True)
# Out:
# Load edges in 0.00 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 287, Num edges: 13664
# Metadata: {'dataname': 'sc_GEM', 'filter_edge': False, 'num_cells': 224, 'num_genes': 61, 'num_omics': 2, 'num_nodes': 287, 'orig_edges': 13664, 'num_edges': 13664, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 63, 'omics_dims': [59, 59], 'raw_data': {'expr': './data/sc_GEM/expression_data.csv', 'methy': './data/sc_GEM/methylation_data.csv'}, 'cell_key': 'Cell ID', 'normalize_stats': []}
# Update metadata: {'dataname': 'sc_GEM', 'filter_edge': False, 'num_cells': 224, 'num_genes': 61, 'num_omics': 2, 'num_nodes': 287, 'orig_edges': 13664, 'num_edges': 13664, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 63, 'omics_dims': [59, 59], 'raw_data': {'expr': './data/sc_GEM/expression_data.csv', 'methy': './data/sc_GEM/methylation_data.csv'}, 'cell_key': 'Cell ID', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [224, 61, 2]
# num_edges 13664
# Normalized, min_val [0.] max_val [25.4359833]
# train_data (10931, 3) train_weight (10931,) test_data (2733, 3) test_weight (2733,)
# Save to data/sc_GEM
# Load edges in 0.01 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 378, Num edges: 34860
# Metadata: {'dataname': 'PEA_STA', 'filter_edge': False, 'num_cells': 210, 'num_genes': 166, 'num_omics': 2, 'num_nodes': 378, 'orig_edges': 34860, 'num_edges': 34860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 168, 'omics_dims': [141, 141], 'raw_data': {'expr': './data/PEA_STA/expression_data.csv', 'protein': './data/PEA_STA/protein_data.csv'}, 'cell_key': 'Cells '}
# Update metadata: {'dataname': 'PEA_STA', 'filter_edge': False, 'num_cells': 210, 'num_genes': 166, 'num_omics': 2, 'num_nodes': 378, 'orig_edges': 34860, 'num_edges': 34860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 168, 'omics_dims': [141, 141], 'raw_data': {'expr': './data/PEA_STA/expression_data.csv', 'protein': './data/PEA_STA/protein_data.csv'}, 'cell_key': 'Cells ', 'normalization': True, 'train_size': 0.8}
# nums_type [210, 166, 2]
# num_edges 34860
# Normalized, min_val [0.] max_val [9.391]
# train_data (27888, 3) train_weight (27888,) test_data (6972, 3) test_weight (6972,)
# Save to data/PEA_STA
# Load edges in 0.25 seconds.
# Load nodes in 0.01 seconds.
# Num nodes: 8939, Num edges: 883700
# Metadata: {'dataname': 'sci_CAR', 'filter_edge': False, 'num_cells': 8837, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 8939, 'orig_edges': 883700, 'num_edges': 883700, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/sci_CAR/ATAC_lsi.csv', 'rna': './data/sci_CAR/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': []}
# Update metadata: {'dataname': 'sci_CAR', 'filter_edge': False, 'num_cells': 8837, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 8939, 'orig_edges': 883700, 'num_edges': 883700, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/sci_CAR/ATAC_lsi.csv', 'rna': './data/sci_CAR/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [8837, 100, 2]
# num_edges 883700
# Normalized, min_val [-87.66184599] max_val [91.21996058]
# train_data (706960, 3) train_weight (706960,) test_data (176740, 3) test_weight (176740,)
# Save to data/sci_CAR
# Load edges in 1.74 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 6806, Num edges: 7917860
# Metadata: {'dataname': 'SCoPE2', 'filter_edge': False, 'num_cells': 1490, 'num_genes': 5314, 'num_omics': 2, 'num_nodes': 6806, 'orig_edges': 7917860, 'num_edges': 7917860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 5316, 'omics_dims': [3042, 3042], 'raw_data': {'expr': './data/SCoPE2/expression_data.csv', 'protein': './data/SCoPE2/protein_data.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': []}
# Update metadata: {'dataname': 'SCoPE2', 'filter_edge': False, 'num_cells': 1490, 'num_genes': 5314, 'num_omics': 2, 'num_nodes': 6806, 'orig_edges': 7917860, 'num_edges': 7917860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 5316, 'omics_dims': [3042, 3042], 'raw_data': {'expr': './data/SCoPE2/expression_data.csv', 'protein': './data/SCoPE2/protein_data.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [1490, 5314, 2]
# num_edges 7917860
# Normalized, min_val [-2.5970583] max_val [3.02659645]
# train_data (6334288, 3) train_weight (6334288,) test_data (1583572, 3) test_weight (1583572,)
# Save to data/SCoPE2
# Load edges in 0.25 seconds.
# Load nodes in 0.01 seconds.
# Num nodes: 10411, Num edges: 1030900
# Metadata: {'dataname': 'SNARE_seq_adult_mouse', 'filter_edge': False, 'num_cells': 10309, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 10411, 'orig_edges': 1030900, 'num_edges': 1030900, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_adult_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_adult_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': []}
# Update metadata: {'dataname': 'SNARE_seq_adult_mouse', 'filter_edge': False, 'num_cells': 10309, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 10411, 'orig_edges': 1030900, 'num_edges': 1030900, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_adult_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_adult_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [10309, 100, 2]
# num_edges 1030900
# Normalized, min_val [-78.50828445] max_val [80.0853005]
# train_data (824720, 3) train_weight (824720,) test_data (206180, 3) test_weight (206180,)
# Save to data/SNARE_seq_adult_mouse
# Load edges in 0.12 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 5183, Num edges: 508100
# Metadata: {'dataname': 'SNARE_seq_neonatal_mouse', 'filter_edge': False, 'num_cells': 5081, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 5183, 'orig_edges': 508100, 'num_edges': 508100, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_neonatal_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_neonatal_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': []}
# Update metadata: {'dataname': 'SNARE_seq_neonatal_mouse', 'filter_edge': False, 'num_cells': 5081, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 5183, 'orig_edges': 508100, 'num_edges': 508100, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_neonatal_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_neonatal_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [5081, 100, 2]
# num_edges 508100
# Normalized, min_val [-57.42046466] max_val [58.72861175]
# train_data (406480, 3) train_weight (406480,) test_data (101620, 3) test_weight (101620,)
# Save to data/SNARE_seq_neonatal_mouse
# Load edges in 4.02 seconds.
# Load nodes in 0.02 seconds.
# Num nodes: 44912, Num edges: 312736781
# Metadata: {'dataname': 'CITE_seq', 'filter_edge': False, 'num_cells': 8617, 'num_genes': 36293, 'num_omics': 2, 'num_nodes': 44912, 'orig_edges': 312736781, 'num_edges': 312736781, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 36295, 'omics_dims': [36280, 13], 'raw_data': {'expr': './data/CITE_seq/expression_data.csv', 'protein': './data/CITE_seq/protein_data.csv'}, 'cell_key': 'cell ID', 'normalize_stats': []}
# Update metadata: {'dataname': 'CITE_seq', 'filter_edge': False, 'num_cells': 8617, 'num_genes': 36293, 'num_omics': 2, 'num_nodes': 44912, 'orig_edges': 312736781, 'num_edges': 312736781, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 36295, 'omics_dims': [36280, 13], 'raw_data': {'expr': './data/CITE_seq/expression_data.csv', 'protein': './data/CITE_seq/protein_data.csv'}, 'cell_key': 'cell ID', 'normalize_stats': [], 'normalization': True, 'train_size': 0.8}
# nums_type [8617, 36293, 2]
# num_edges 312736781
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[6], line 9
#       7     print('Failed to load', subdir, 'except', e)
#       8     continue
# ----> 9 convert_to_hypersagnn_format(hg, TRAIN_SIZE, subdir, normalization=True)
#
# File ~/GuidedStudy/Code/SCOIT/hgnn/hypergraph.py:485, in convert_to_hypersagnn_format(hg, train_size, save_dir, normalization)
#     481 from sklearn.model_selection import train_test_split
#     483 train_data, test_data, train_weight, test_weight = train_test_split(edges_data, edges_weight,
#     484                                                                       train_size=train_size)
# --> 485 if normalization:
#     486     scaler = MinMaxScaler()
#     487     train_weight = scaler.fit_transform(train_weight.reshape(-1, 1)).reshape(-1)
#
# File /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/utils/_param_validation.py:216, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     210 try:
#     211     with config_context(
#     212         skip_parameter_validation=(
#     213             prefer_skip_nested_validation or global_skip_validation
#     214         )
#     215     ):
# --> 216         return func(*args, **kwargs)
#     217 except InvalidParameterError as e:
#     218     # When the function is just a wrapper around an estimator, we allow
#     219     # the function to delegate validation to the estimator, but we replace
#     220     # the name of the estimator by the name of the function in the error
#     221     # message to avoid confusion.
#     222     msg = re.sub(
#     223         r"parameter of \w+ must be",
#     224         f"parameter of {func.__qualname__} must be",
#     225         str(e),
#     226     )
#
# File /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/model_selection/_split.py:2876, in train_test_split(test_size, train_size, random_state, shuffle, stratify, *arrays)
#    2872     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2874 train, test = ensure_common_namespace_device(arrays[0], train, test)
# -> 2876 return list(
#    2877     chain.from_iterable(
#    2878         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2879     )
#    2880 )
#
# File /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/model_selection/_split.py:2878, in <genexpr>(.0)
#    2872     train, test = next(cv.split(X=arrays[0], y=stratify))
#    2874 train, test = ensure_common_namespace_device(arrays[0], train, test)
#    2876 return list(
#    2877     chain.from_iterable(
# -> 2878         (_safe_indexing(a, train), _safe_indexing(a, test)) for a in arrays
#    2879     )
#    2880 )
#
# File /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/utils/_indexing.py:270, in _safe_indexing(X, indices, axis)
#     268     return _polars_indexing(X, indices, indices_dtype, axis=axis)
#     269 elif hasattr(X, "shape"):
# --> 270     return _array_indexing(X, indices, indices_dtype, axis=axis)
#     271 else:
#     272     return _list_indexing(X, indices, indices_dtype)
#
# File /public/congfeng4/miniconda3/envs/py39/lib/python3.9/site-packages/sklearn/utils/_indexing.py:36, in _array_indexing(array, key, key_dtype, axis)
#      34 if isinstance(key, tuple):
#      35     key = list(key)
# ---> 36 return array[key, ...] if axis == 0 else array[:, key]
#
# MemoryError: Unable to allocate 5.59 GiB for an array with shape (250189424, 3) and data type int64
