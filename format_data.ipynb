# %% [markdown]
# ## Investigate the Hyper-SAGNN Format.

# %%
import numpy as np

# %%
train_data = np.load('./data/GPS/train_data.npz', allow_pickle=True)
test_data = np.load('./data/GPS/test_data.npz', allow_pickle=True)

train_data['train_data'].shape, test_data['test_data'].shape
# Out:
# ((1154, 3), (282, 3))

# %%
num_test = test_data['test_data'].shape[0]
num_train = train_data['train_data'].shape[0]
total = num_test + num_train
train_size = num_train / total
train_size
# Out:
# 0.8036211699164345

# %%
td = train_data['train_data']
td
# Out:
# array([[ 93,  57,   4],
#        [ 17,   7,   0],
#        [ 26,  13,   4],
#        ...,
#        [108,  15,   1],
#        [113,   1,   0],
#        [141,  41,   3]])

# %%
np.max(td, 0)
# Out:
# array([145,  69,   4])

# %%
train_data['nums_type']
# Out:
# array([146,  70,   5])

# %%
test_data['nums_type']
# Out:
# array([146,  70,   5])

# %%
train = np.load('./data/sc_GEM/train_data.npz')

# %%
train['nums_type']
# Out:
# array([224,  61,   2])

# %%
td = train['train_data']

# %%
np.max(td, 0)
# Out:
# array([223,  60,   1])

# %% [markdown]
# ## Convert all graphs to Hyper_SAGNN format.

# %%
try:
   import sys
   del sys.modules['hgnn.hypergraph']
except:
    pass

from hgnn.hypergraph import *

# %%
TRAIN_SIZE = 0.8

# %%
hg = load_graph('./data/sc_GEM')

convert_to_hypersagnn_format(hg, train_size=TRAIN_SIZE, save_dir='./data/sc_GEM')
# Out:
# Load edges in 0.01 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 287, Num edges: 13664
# Metadata: {'dataname': 'sc_GEM', 'filter_edge': False, 'num_cells': 224, 'num_genes': 61, 'num_omics': 2, 'num_nodes': 287, 'orig_edges': 13664, 'num_edges': 13664, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 63, 'omics_dims': [59, 59], 'raw_data': {'expr': './data/sc_GEM/expression_data.csv', 'methy': './data/sc_GEM/methylation_data.csv'}, 'cell_key': 'Cell ID'}
# nums_type [224, 61, 2]
# num_edges 13664
# train_data (10931, 3) train_weight (10931,) test_data (2733, 3) test_weight (2733,)
# Save to data/sc_GEM

# %%
hg.num_edges, hg.num_nodes
# Out:
# (13664, 287)

# %%
TRAIN_SIZE = 0.9

for subdir in Path('./data').iterdir():
    if not subdir.is_dir():
        continue
    try:
        hg = load_graph(subdir)
    except Exception as e:
        print('Failed to load', subdir, 'except', e)
        continue
    convert_to_hypersagnn_format(hg, TRAIN_SIZE, subdir)
# Out:
# Load edges in 0.01 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 287, Num edges: 13664
# Metadata: {'dataname': 'sc_GEM', 'filter_edge': False, 'num_cells': 224, 'num_genes': 61, 'num_omics': 2, 'num_nodes': 287, 'orig_edges': 13664, 'num_edges': 13664, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 63, 'omics_dims': [59, 59], 'raw_data': {'expr': './data/sc_GEM/expression_data.csv', 'methy': './data/sc_GEM/methylation_data.csv'}, 'cell_key': 'Cell ID'}
# nums_type [224, 61, 2]
# num_edges 13664
# train_data (12297, 3) train_weight (12297,) test_data (1367, 3) test_weight (1367,)
# Save to data/sc_GEM
# Load edges in 0.00 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 378, Num edges: 9977
# Detected isolated ndoes {64, 5, 69, 39, 71, 138, 61, 85, 87, 28, 29, 63}
# Failed to load data/PEA_STA except
# Load edges in 0.23 seconds.
# Load nodes in 0.01 seconds.
# Num nodes: 8939, Num edges: 834002
# ...
