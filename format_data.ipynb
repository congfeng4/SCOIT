# %% [markdown]
# ## Convert all graphs to Hyper_SAGNN format.

# %%
try:
   import sys
   del sys.modules['hgnn.hypergraph']
except:
    pass

from hgnn.hypergraph import *
from pathlib import Path

TRAIN_SIZE = 0.9

# %%
for subdir in Path('./data').iterdir():
    if not subdir.is_dir():
        continue
    try:
        hg = load_graph(subdir)
    except Exception as e:
        print('Failed to load', subdir, 'except', e)
        continue
    convert_to_hypersagnn_format(hg, TRAIN_SIZE, subdir)
# Out:
# Load edges in 0.01 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 287, Num edges: 13664
# Metadata: {'dataname': 'sc_GEM', 'filter_edge': False, 'num_cells': 224, 'num_genes': 61, 'num_omics': 2, 'num_nodes': 287, 'orig_edges': 13664, 'num_edges': 13664, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 63, 'omics_dims': [59, 59], 'raw_data': {'expr': './data/sc_GEM/expression_data.csv', 'methy': './data/sc_GEM/methylation_data.csv'}, 'cell_key': 'Cell ID'}
# nums_type [224, 61, 2]
# num_edges 13664
# Normalized, min_val [0.] max_val [25.4359833]
# train_data (12297, 3) train_weight (12297,) test_data (1367, 3) test_weight (1367,)
# Save to data/sc_GEM
# Load edges in 0.01 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 378, Num edges: 34860
# Metadata: {'dataname': 'PEA_STA', 'filter_edge': False, 'num_cells': 210, 'num_genes': 166, 'num_omics': 2, 'num_nodes': 378, 'orig_edges': 34860, 'num_edges': 34860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 168, 'omics_dims': [141, 141], 'raw_data': {'expr': './data/PEA_STA/expression_data.csv', 'protein': './data/PEA_STA/protein_data.csv'}, 'cell_key': 'Cells '}
# nums_type [210, 166, 2]
# num_edges 34860
# Normalized, min_val [0.] max_val [9.391]
# train_data (31374, 3) train_weight (31374,) test_data (3486, 3) test_weight (3486,)
# Save to data/PEA_STA
# Load edges in 0.26 seconds.
# Load nodes in 0.01 seconds.
# Num nodes: 8939, Num edges: 883700
# Metadata: {'dataname': 'sci_CAR', 'filter_edge': False, 'num_cells': 8837, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 8939, 'orig_edges': 883700, 'num_edges': 883700, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/sci_CAR/ATAC_lsi.csv', 'rna': './data/sci_CAR/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0'}
# nums_type [8837, 100, 2]
# num_edges 883700
# Normalized, min_val [-87.66184599] max_val [91.21996058]
# train_data (795330, 3) train_weight (795330,) test_data (88370, 3) test_weight (88370,)
# Save to data/sci_CAR
# Load edges in 1.89 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 6806, Num edges: 7917860
# Metadata: {'dataname': 'SCoPE2', 'filter_edge': False, 'num_cells': 1490, 'num_genes': 5314, 'num_omics': 2, 'num_nodes': 6806, 'orig_edges': 7917860, 'num_edges': 7917860, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 5316, 'omics_dims': [3042, 3042], 'raw_data': {'expr': './data/SCoPE2/expression_data.csv', 'protein': './data/SCoPE2/protein_data.csv'}, 'cell_key': 'Unnamed: 0'}
# nums_type [1490, 5314, 2]
# num_edges 7917860
# Normalized, min_val [-2.5970583] max_val [3.02659645]
# train_data (7126074, 3) train_weight (7126074,) test_data (791786, 3) test_weight (791786,)
# Save to data/SCoPE2
# Load edges in 0.27 seconds.
# Load nodes in 0.01 seconds.
# Num nodes: 10411, Num edges: 1030900
# Metadata: {'dataname': 'SNARE_seq_adult_mouse', 'filter_edge': False, 'num_cells': 10309, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 10411, 'orig_edges': 1030900, 'num_edges': 1030900, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_adult_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_adult_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0'}
# nums_type [10309, 100, 2]
# num_edges 1030900
# Normalized, min_val [-78.50828445] max_val [86.65126883]
# train_data (927810, 3) train_weight (927810,) test_data (103090, 3) test_weight (103090,)
# Save to data/SNARE_seq_adult_mouse
# Load edges in 0.13 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 5183, Num edges: 508100
# Metadata: {'dataname': 'SNARE_seq_neonatal_mouse', 'filter_edge': False, 'num_cells': 5081, 'num_genes': 100, 'num_omics': 2, 'num_nodes': 5183, 'orig_edges': 508100, 'num_edges': 508100, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 102, 'omics_dims': [50, 50], 'raw_data': {'atac': './data/SNARE_seq_neonatal_mouse/ATAC_lsi.csv', 'rna': './data/SNARE_seq_neonatal_mouse/RNA_pca.csv'}, 'cell_key': 'Unnamed: 0'}
# nums_type [5081, 100, 2]
# num_edges 508100
# Normalized, min_val [-57.42046466] max_val [58.72861175]
# train_data (457290, 3) train_weight (457290,) test_data (50810, 3) test_weight (50810,)
# Save to data/SNARE_seq_neonatal_mouse
# Load edges in 5.00 seconds.
# Load nodes in 0.02 seconds.
# Num nodes: 44912, Num edges: 312736781
# Metadata: {'dataname': 'CITE_seq', 'filter_edge': False, 'num_cells': 8617, 'num_genes': 36293, 'num_omics': 2, 'num_nodes': 44912, 'orig_edges': 312736781, 'num_edges': 312736781, 'omics_offset': 0, 'gene_offset': 2, 'cell_offset': 36295, 'omics_dims': [36280, 13], 'raw_data': {'expr': './data/CITE_seq/expression_data.csv', 'protein': './data/CITE_seq/protein_data.csv'}, 'cell_key': 'cell ID'}
# nums_type [8617, 36293, 2]
# num_edges 312736781
# Normalized, min_val [-2.9184661] max_val [5367.]
# train_data (281463102, 3) train_weight (281463102,) test_data (31273679, 3) test_weight (31273679,)
# Save to data/CITE_seq
# Failed to load data/GPS except [Errno 2] No such file or directory: 'data/GPS/metadata.json'
# Load edges in 0.23 seconds.
# Load nodes in 0.00 seconds.
# Num nodes: 2843, Num edges: 978300
# Metadata: {'dataname': 'scNMT', 'filter_edge': False, 'num_cells': 1940, 'num_genes': 900, 'num_omics': 3, 'num_nodes': 2843, 'orig_edges': 978300, 'num_edges': 978300, 'omics_offset': 0, 'gene_offset': 3, 'cell_offset': 903, 'omics_dims': [300, 300, 300], 'raw_data': {'expr': './data/scNMT/expression_data_300.csv', 'promoter_acc': './data/scNMT/promoter_acc_data_300.csv', 'promoter_methy': './data/scNMT/promoter_methy_data_300.csv'}, 'cell_key': None}
# nums_type [1940, 900, 3]
# num_edges 978300
# Normalized, min_val [0.24926662] max_val [9.89675522]
# train_data (880470, 3) train_weight (880470,) test_data (97830, 3) test_weight (97830,)
# Save to data/scNMT
# Failed to load data/drug except [Errno 2] No such file or directory: 'data/drug/metadata.json'
# Failed to load data/MovieLens except [Errno 2] No such file or directory: 'data/MovieLens/metadata.json'
# Failed to load data/wordnet except [Errno 2] No such file or directory: 'data/wordnet/metadata.json'
