# %%
import numpy as np
import seaborn as sns

# %%
H = np.load('../embeddings.npz', allow_pickle=True)

# %%
H1, H2, H3 = H['embeddings']
H1.shape, H2.shape, H3.shape
# Out:
# ((1490, 6806), (5314, 6806), (2, 6806))

# %%
H1d = H1.toarray()
H2d = H2.toarray()
H3d = H3.toarray()

# %%
def any_column_all_zero(x):
    return np.nonzero(np.all(x == 0, 1))

# %%
any_column_all_zero(H1d), any_column_all_zero(H2d), any_column_all_zero(H3d)
# Out:
# ((array([], dtype=int64),),
#  (array([], dtype=int64),),
#  (array([], dtype=int64),))

# %%
H2d
# Out:
# array([[       nan, 0.03581931,        nan, ..., 0.        ,        nan,
#         0.        ],
#        [       nan,        nan,        nan, ..., 0.        ,        nan,
#         0.        ],
#        [0.14153217,        nan, 0.        , ..., 0.        ,        nan,
#         0.        ],
#        ...,
#        [       nan, 0.        , 0.25809205, ..., 0.        , 0.        ,
#                nan],
#        [0.18078287,        nan, 0.5774101 , ..., 0.        , 0.        ,
#                nan],
#        [0.50653565,        nan, 0.22219677, ...,        nan, 0.        ,
#                nan]], dtype=float32)

# %%
H2d[5, :]
# Out:
# array([0., 0., 0., ..., 0., 0., 0.], dtype=float32)
