# %% [markdown]
# # Cell clustering with SCOIT's embeddings.

# %%
from hgnn.hypergraph import *
from scoit.cell_analysis import *

# %% [markdown]
# ## sc-GEM

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/sc_GEM/cell_embeddings.csv', header=None))
labels = json.load(open('./data/sc_GEM/cell_stage.json'))
umap_visualize(cell_embeddings, labels)
# Out:
# {'NMI': 0.4808920870084839,
#  'ARI': 0.36661670345056635,
#  'FMI': 0.4529923307749305}

# %% [markdown]
# ## PEA-STA

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/PEA_STA/cell_embeddings.csv', header=None))
labels = json.load(open('./data/PEA_STA/cell_stage.json'))
umap_visualize(cell_embeddings, labels)
# Out:
# {'NMI': 0.6334157414507205,
#  'ARI': 0.561005681836063,
#  'FMI': 0.7309823748165141}

# %% [markdown]
# ## SCoPE2

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/SCoPE2/cell_embeddings.csv', header=None))
labels = json.load(open('./data/SCoPE2/cell_stage.json'))
umap_visualize(cell_embeddings, labels)
# Out:
# {'NMI': 0.4208957962845308,
#  'ARI': 0.41104844056896306,
#  'FMI': 0.7406842881338934}

# %% [markdown]
# ## SNARE_seq_adult_mouse

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/SNARE_seq_adult_mouse/cell_embeddings.csv', header=None))
labels = json.load(open('./data/SNARE_seq_adult_mouse/cell_stage.json'))
umap_visualize(cell_embeddings, labels, palette="viridis", s=5)
# Out:
# {'NMI': 0.5881410696063322,
#  'ARI': 0.36669503477033716,
#  'FMI': 0.4302372450562646}

# %% [markdown]
# ## SNARE_seq_neonatal_mouse

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/SNARE_seq_neonatal_mouse/cell_embeddings.csv', header=None))
labels = json.load(open('./data/SNARE_seq_neonatal_mouse/cell_stage.json'))
umap_visualize(cell_embeddings, labels, palette="viridis", s=5)
# Out:
# {'NMI': 0.4507817226561637,
#  'ARI': 0.28363688792335034,
#  'FMI': 0.3368890607324291}

# %% [markdown]
# ## sci_CAR

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/sci_CAR/cell_embeddings.csv', header=None))
labels = json.load(open('./data/sci_CAR/cell_stage.json'))
umap_visualize(cell_embeddings, labels, palette="viridis", s=5)
# Out:
# {'NMI': 0.5671404490891471,
#  'ARI': 0.4295178106285551,
#  'FMI': 0.5201192329857794}

# %% [markdown]
# ## scNMT

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/scNMT/cell_embeddings.csv', header=None))
labels = json.load(open('./data/scNMT/cell_stage.json'))
umap_visualize(cell_embeddings, labels, palette="viridis", s=5)
# Out:
# {'NMI': 0.31659682506490655,
#  'ARI': 0.3232167719126356,
#  'FMI': 0.5812481310349656}

# %% [markdown]
# ## CITE-seq

# %%
cell_embeddings = (pd.read_csv('./embeddings/scoit/CITE_seq/cell_embeddings.csv', header=None))
labels = json.load(open('./data/CITE_seq/cell_stage.json'))
umap_visualize(cell_embeddings, labels, palette="viridis", s=5, eval_use_umap=True)
# Out:
# {'NMI': 0.7240258209877225,
#  'ARI': 0.8474534213325848,
#  'FMI': 0.8893721135725468}
